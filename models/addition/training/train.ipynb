# %%
# %cd ..
# Out:
# /home/can/39c3-transformer-workshop

# %%
import torch as th

# %%
with open("datasets/addition/dataset_train.pt", "rb") as f:
    train_BT = th.load(f, weights_only=False)

with open("datasets/addition/dataset_test.pt", "rb") as f:
    test_BT = th.load(f, weights_only=False)

train_BT
# Out:
# tensor([[1, 0, 6, 1],
#         [0, 3, 6, 3],
#         [5, 0, 6, 5],
#         [4, 4, 6, 2],
#         [2, 2, 6, 4],
#         [3, 5, 6, 2],
#         [2, 4, 6, 0],
#         [5, 4, 6, 3],
#         [3, 4, 6, 1],
#         [1, 5, 6, 0],
#         [0, 4, 6, 4],
#         [4, 1, 6, 5],
#         [1, 4, 6, 5],
#         [5, 5, 6, 4],
#         [4, 3, 6, 1],
#         [5, 1, 6, 0],
#         [2, 3, 6, 5],
#         [1, 3, 6, 4]])
